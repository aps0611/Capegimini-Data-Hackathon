# %% [markdown]
# <a href="https://colab.research.google.com/github/aps0611/Capegimini-Data-Hackathon/blob/aps0611/book1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

pd.set_option('display.max_columns', None)

# %% [markdown]
# # The major crops selected in this model are:
#
# `corn cotton and sorghum`

# %%
df_cotton = pd.read_csv("https://raw.githubusercontent.com/aps0611/Capegimini-Data-Hackathon/aps0611/dataset/Texas/crops/cotton_1.csv")
df_cotton.head(5)
# Out:
#   Program  Year Period  Week Ending Geo Level  State  State ANSI Ag District  \
# 0  CENSUS  2017   YEAR          NaN    COUNTY  TEXAS          48  BLACKLANDS
# 1  CENSUS  2017   YEAR          NaN    COUNTY  TEXAS          48  BLACKLANDS
# 2  CENSUS  2017   YEAR          NaN    COUNTY  TEXAS          48  BLACKLANDS
# 3  CENSUS  2017   YEAR          NaN    COUNTY  TEXAS          48  BLACKLANDS
# 4  CENSUS  2017   YEAR          NaN    COUNTY  TEXAS          48  BLACKLANDS
#
#    Ag District Code   County  County ANSI  Zip Code  Region  watershed_code  \
# 0                40     BELL           27       NaN     NaN               0
# 1                40   BOSQUE           35       NaN     NaN               0
# 2                40   COLLIN           85       NaN     NaN               0
# 3                40    COOKE           97       NaN     NaN               0
# 4                40  CORYELL           99       NaN     NaN               0
#
# ...

# %%
df_cotton.shape
# Out:
# (174, 21)

# %%
df_cotton['COTTON-AREA-ACRES'] = df_cotton['Value']
df_cotton.head()
# Out:
#   Program  Year Period  Week Ending Geo Level  State  State ANSI Ag District  \
# 0  CENSUS  2017   YEAR          NaN    COUNTY  TEXAS          48  BLACKLANDS
# 1  CENSUS  2017   YEAR          NaN    COUNTY  TEXAS          48  BLACKLANDS
# 2  CENSUS  2017   YEAR          NaN    COUNTY  TEXAS          48  BLACKLANDS
# 3  CENSUS  2017   YEAR          NaN    COUNTY  TEXAS          48  BLACKLANDS
# 4  CENSUS  2017   YEAR          NaN    COUNTY  TEXAS          48  BLACKLANDS
#
#    Ag District Code   County  County ANSI  Zip Code  Region  watershed_code  \
# 0                40     BELL           27       NaN     NaN               0
# 1                40   BOSQUE           35       NaN     NaN               0
# 2                40   COLLIN           85       NaN     NaN               0
# 3                40    COOKE           97       NaN     NaN               0
# 4                40  CORYELL           99       NaN     NaN               0
#
# ...

# %%
df_cotton.drop(['Program','Region','Commodity','Zip Code', 'CV (%)','Year', 
               'Period', 'Week Ending', 'watershed_code', 'Watershed','Data Item',
               'Domain', 'Domain Category', 'Value'], 
              inplace = True,
              axis = 'columns')
df_cotton.head(3)
# Out:
#   Geo Level  State  State ANSI Ag District  Ag District Code  County  \
# 0    COUNTY  TEXAS          48  BLACKLANDS                40    BELL
# 1    COUNTY  TEXAS          48  BLACKLANDS                40  BOSQUE
# 2    COUNTY  TEXAS          48  BLACKLANDS                40  COLLIN
#
#    County ANSI COTTON-AREA-ACRES
# 0           27          6,261.00
# 1           35          6,243.00
# 2           85            840.00

# %%
len(df_cotton['County'].unique())
# Out:
# 174

# %% [markdown]
# # Corn

# %%
df_corn = pd.read_csv('https://raw.githubusercontent.com/aps0611/Capegimini-Data-Hackathon/aps0611/dataset/Texas/crops/corn_1.csv')

# %%
df_corn.head(5)
# Out:
#   Program  Year Period  Week Ending Geo Level  State  State ANSI Ag District  \
# 0  CENSUS  2017   YEAR          NaN    COUNTY  TEXAS          48  BLACKLANDS
# 1  CENSUS  2017   YEAR          NaN    COUNTY  TEXAS          48  BLACKLANDS
# 2  CENSUS  2017   YEAR          NaN    COUNTY  TEXAS          48  BLACKLANDS
# 3  CENSUS  2017   YEAR          NaN    COUNTY  TEXAS          48  BLACKLANDS
# 4  CENSUS  2017   YEAR          NaN    COUNTY  TEXAS          48  BLACKLANDS
#
#    Ag District Code   County  County ANSI  Zip Code  Region  watershed_code  \
# 0                40     BELL           27       NaN     NaN               0
# 1                40   BOSQUE           35       NaN     NaN               0
# 2                40   COLLIN           85       NaN     NaN               0
# 3                40    COOKE           97       NaN     NaN               0
# 4                40  CORYELL           99       NaN     NaN               0
#
# ...

# %%
df_corn.shape
# Out:
# (176, 21)

# %%
df_corn.rename(columns = {'Value': 'CORN-GRAIN-ACRES'}, inplace = True)
df_corn.head(5)
# Out:
#   Program  Year Period  Week Ending Geo Level  State  State ANSI Ag District  \
# 0  CENSUS  2017   YEAR          NaN    COUNTY  TEXAS          48  BLACKLANDS
# 1  CENSUS  2017   YEAR          NaN    COUNTY  TEXAS          48  BLACKLANDS
# 2  CENSUS  2017   YEAR          NaN    COUNTY  TEXAS          48  BLACKLANDS
# 3  CENSUS  2017   YEAR          NaN    COUNTY  TEXAS          48  BLACKLANDS
# 4  CENSUS  2017   YEAR          NaN    COUNTY  TEXAS          48  BLACKLANDS
#
#    Ag District Code   County  County ANSI  Zip Code  Region  watershed_code  \
# 0                40     BELL           27       NaN     NaN               0
# 1                40   BOSQUE           35       NaN     NaN               0
# 2                40   COLLIN           85       NaN     NaN               0
# 3                40    COOKE           97       NaN     NaN               0
# 4                40  CORYELL           99       NaN     NaN               0
#
# ...

# %%
df_corn.drop(['Program','Region','Commodity','Zip Code', 'CV (%)','Year', 
               'Period', 'Week Ending', 'watershed_code', 'Watershed','Data Item',
               'Domain', 'Domain Category'], inplace = True, axis = 'columns')
df_corn
# Out:
#     Geo Level  State  State ANSI  Ag District  Ag District Code     County  \
# 0      COUNTY  TEXAS          48   BLACKLANDS                40       BELL
# 1      COUNTY  TEXAS          48   BLACKLANDS                40     BOSQUE
# 2      COUNTY  TEXAS          48   BLACKLANDS                40     COLLIN
# 3      COUNTY  TEXAS          48   BLACKLANDS                40      COOKE
# 4      COUNTY  TEXAS          48   BLACKLANDS                40    CORYELL
# ..        ...    ...         ...          ...               ...        ...
# 171    COUNTY  TEXAS          48  UPPER COAST                90    LIBERTY
# 172    COUNTY  TEXAS          48  UPPER COAST                90  MATAGORDA
# 173    COUNTY  TEXAS          48  UPPER COAST                90     ORANGE
# 174    COUNTY  TEXAS          48  UPPER COAST                90   VICTORIA
# 175    COUNTY  TEXAS          48  UPPER COAST                90    WHARTON
#
#      County ANSI CORN-GRAIN-ACRES
# ...

# %%
# combine the two dataframes
df_combined = pd.merge(df_cotton, df_corn, on = ['Geo Level','State','State ANSI','Ag District',
                                                'Ag District Code','County','County ANSI'], how = 'outer')
df_combined
# Out:
#     Geo Level  State  State ANSI  Ag District  Ag District Code    County  \
# 0      COUNTY  TEXAS          48   BLACKLANDS                40      BELL
# 1      COUNTY  TEXAS          48   BLACKLANDS                40    BOSQUE
# 2      COUNTY  TEXAS          48   BLACKLANDS                40    COLLIN
# 3      COUNTY  TEXAS          48   BLACKLANDS                40     COOKE
# 4      COUNTY  TEXAS          48   BLACKLANDS                40   CORYELL
# ..        ...    ...         ...          ...               ...       ...
# 204    COUNTY  TEXAS          48  SOUTH TEXAS                96  LA SALLE
# 205    COUNTY  TEXAS          48  SOUTH TEXAS                96  MCMULLEN
# 206    COUNTY  TEXAS          48  UPPER COAST                90  CHAMBERS
# 207    COUNTY  TEXAS          48  UPPER COAST                90   LIBERTY
# 208    COUNTY  TEXAS          48  UPPER COAST                90    ORANGE
#
#      County ANSI COTTON-AREA-ACRES CORN-GRAIN-ACRES
# ...

# %% [markdown]
# # Sorghum

# %%
df_sorghum = pd.read_csv('https://raw.githubusercontent.com/aps0611/Capegimini-Data-Hackathon/aps0611/dataset/Texas/crops/sorghum_1.csv')
df_sorghum.head(3)
# Out:
#   Program  Year Period  Week Ending Geo Level  State  State ANSI Ag District  \
# 0  CENSUS  2017   YEAR          NaN    COUNTY  TEXAS          48  BLACKLANDS
# 1  CENSUS  2017   YEAR          NaN    COUNTY  TEXAS          48  BLACKLANDS
# 2  CENSUS  2017   YEAR          NaN    COUNTY  TEXAS          48  BLACKLANDS
#
#    Ag District Code  County  County ANSI  Zip Code  Region  watershed_code  \
# 0                40    BELL           27       NaN     NaN               0
# 1                40  BOSQUE           35       NaN     NaN               0
# 2                40  COLLIN           85       NaN     NaN               0
#
#    Watershed Commodity                         Data Item Domain  \
# 0        NaN   SORGHUM  SORGHUM, GRAIN - ACRES HARVESTED  TOTAL
# 1        NaN   SORGHUM  SORGHUM, GRAIN - ACRES HARVESTED  TOTAL
# 2        NaN   SORGHUM  SORGHUM, GRAIN - ACRES HARVESTED  TOTAL
#
#   Domain Category     Value CV (%)
# 0   NOT SPECIFIED  7,264.00   18.3
# ...

# %%
df_sorghum.drop(['Program','Region','Commodity','Zip Code', 'CV (%)','Year', 
               'Period', 'Week Ending', 'watershed_code', 'Watershed','Data Item',
               'Domain', 'Domain Category'], inplace = True, axis = 'columns')

# %%
df_sorghum.rename(columns = {'Value': 'SORGHUM-ACRES'}, inplace = True)
df_sorghum.head(5)
# Out:
#   Geo Level  State  State ANSI Ag District  Ag District Code   County  \
# 0    COUNTY  TEXAS          48  BLACKLANDS                40     BELL
# 1    COUNTY  TEXAS          48  BLACKLANDS                40   BOSQUE
# 2    COUNTY  TEXAS          48  BLACKLANDS                40   COLLIN
# 3    COUNTY  TEXAS          48  BLACKLANDS                40    COOKE
# 4    COUNTY  TEXAS          48  BLACKLANDS                40  CORYELL
#
#    County ANSI SORGHUM-ACRES
# 0           27      7,264.00
# 1           35      1,299.00
# 2           85      7,102.00
# 3           97      4,870.00
# 4           99      4,705.00

# %%
df_combined = pd.merge(df_combined, df_sorghum, on = ['Geo Level','State','State ANSI','Ag District',
                                                'Ag District Code','County','County ANSI'], how = 'outer')
df_combined
# Out:
#     Geo Level  State  State ANSI    Ag District  Ag District Code     County  \
# 0      COUNTY  TEXAS          48     BLACKLANDS                40       BELL
# 1      COUNTY  TEXAS          48     BLACKLANDS                40     BOSQUE
# 2      COUNTY  TEXAS          48     BLACKLANDS                40     COLLIN
# 3      COUNTY  TEXAS          48     BLACKLANDS                40      COOKE
# 4      COUNTY  TEXAS          48     BLACKLANDS                40    CORYELL
# ..        ...    ...         ...            ...               ...        ...
# 208    COUNTY  TEXAS          48    UPPER COAST                90     ORANGE
# 209    COUNTY  TEXAS          48  CROSS TIMBERS                30   MONTAGUE
# 210    COUNTY  TEXAS          48  CROSS TIMBERS                30   STEPHENS
# 211    COUNTY  TEXAS          48    SOUTH TEXAS                96      DUVAL
# 212    COUNTY  TEXAS          48    UPPER COAST                90  JEFFERSON
#
# ...

# %% [markdown]
# # Cattle:

# %%
df_cattle = pd.read_csv('https://raw.githubusercontent.com/aps0611/Capegimini-Data-Hackathon/aps0611/dataset/Texas/Livestock/cattle.csv')
df_cattle.head(3)
# Out:
#   Program  Year        Period  Week Ending Geo Level  State  State ANSI  \
# 0  SURVEY  2022  FIRST OF JAN          NaN    COUNTY  TEXAS          48
# 1  SURVEY  2022  FIRST OF JAN          NaN    COUNTY  TEXAS          48
# 2  SURVEY  2022  FIRST OF JAN          NaN    COUNTY  TEXAS          48
#
#   Ag District  Ag District Code          County  County ANSI  Zip Code  \
# 0         NaN                99  OTHER COUNTIES          NaN       NaN
# 1  BLACKLANDS                40            BELL         27.0       NaN
# 2  BLACKLANDS                40          BOSQUE         35.0       NaN
#
#    Region  watershed_code  Watershed Commodity Domain Domain Category  \
# 0     NaN               0        NaN    CATTLE  TOTAL   NOT SPECIFIED
# 1     NaN               0        NaN    CATTLE  TOTAL   NOT SPECIFIED
# 2     NaN               0        NaN    CATTLE  TOTAL   NOT SPECIFIED
#
#   CATTLE, COWS, BEEF - INVENTORY  -  <b>VALUE</b>  \
# 0                                       1,274,000
# ...

# %%
df_cattle = df_cattle[['Geo Level', 'State', 'State ANSI', 'Ag District', 'Ag District Code',
       'County', 'County ANSI',
       'CATTLE, COWS, BEEF - INVENTORY  -  <b>VALUE</b>',
       'CATTLE, COWS, MILK - INVENTORY  -  <b>VALUE</b>',
       'CATTLE, INCL CALVES - INVENTORY  -  <b>VALUE</b>'
       ]]

# %%
df_cattle.columns
# Out:
# Index(['Geo Level', 'State', 'State ANSI', 'Ag District', 'Ag District Code',
#        'County', 'County ANSI',
#        'CATTLE, COWS, BEEF - INVENTORY  -  <b>VALUE</b>',
#        'CATTLE, COWS, MILK - INVENTORY  -  <b>VALUE</b>',
#        'CATTLE, INCL CALVES - INVENTORY  -  <b>VALUE</b>'],
#       dtype='object')

# %%
df_cattle
# Out:
#     Geo Level  State  State ANSI  Ag District  Ag District Code  \
# 0      COUNTY  TEXAS          48          NaN                99
# 1      COUNTY  TEXAS          48   BLACKLANDS                40
# 2      COUNTY  TEXAS          48   BLACKLANDS                40
# 3      COUNTY  TEXAS          48   BLACKLANDS                40
# 4      COUNTY  TEXAS          48   BLACKLANDS                40
# ..        ...    ...         ...          ...               ...
# 250    COUNTY  TEXAS          48  UPPER COAST                90
# 251    COUNTY  TEXAS          48  UPPER COAST                90
# 252    COUNTY  TEXAS          48  UPPER COAST                90
# 253    COUNTY  TEXAS          48  UPPER COAST                90
# 254    COUNTY  TEXAS          48  UPPER COAST                90
#
#              County  County ANSI  \
# 0    OTHER COUNTIES          NaN
# 1              BELL         27.0
# 2            BOSQUE         35.0
# 3            COLLIN         85.0
# ...

# %%
df_combined = pd.merge(df_combined, df_cattle, on = ['Geo Level','State','State ANSI','Ag District',
                                                'Ag District Code','County','County ANSI'], how = 'outer')
df_combined
# Out:
#     Geo Level  State  State ANSI  Ag District  Ag District Code     County  \
# 0      COUNTY  TEXAS          48   BLACKLANDS                40       BELL
# 1      COUNTY  TEXAS          48   BLACKLANDS                40     BOSQUE
# 2      COUNTY  TEXAS          48   BLACKLANDS                40     COLLIN
# 3      COUNTY  TEXAS          48   BLACKLANDS                40      COOKE
# 4      COUNTY  TEXAS          48   BLACKLANDS                40    CORYELL
# ..        ...    ...         ...          ...               ...        ...
# 250    COUNTY  TEXAS          48  TRANS-PECOS                60   PRESIDIO
# 251    COUNTY  TEXAS          48  TRANS-PECOS                60    TERRELL
# 252    COUNTY  TEXAS          48  TRANS-PECOS                60       WARD
# 253    COUNTY  TEXAS          48  TRANS-PECOS                60    WINKLER
# 254    COUNTY  TEXAS          48  UPPER COAST                90  GALVESTON
#
#      County ANSI COTTON-AREA-ACRES CORN-GRAIN-ACRES SORGHUM-ACRES  \
# ...

# %%
df_precipitation = pd.read_csv('https://raw.githubusercontent.com/aps0611/Capegimini-Data-Hackathon/aps0611/dataset/Texas/precipitation/precipitation.csv')
df_precipitation
# Out:
#         Rank     County  Mean Annual\nPrecipitation (in.)  \
# 0          1     JASPER                             60.57
# 1          2    LIBERTY                             60.52
# 2          3  JEFFERSON                             59.89
# 3          4     ORANGE                             59.00
# 4          5   BRAZORIA                             57.24
# ..       ...        ...                               ...
# 250      251   HUDSPETH                             11.93
# 251      252     REEVES                             11.61
# 252      253    EL PASO                              9.43
# 253      254     LOVING                              9.10
# 254  Average        NaN                             28.87
#
#      Mean Annual\nPrecipitation (cm.)
# 0                            153.8478
# 1                            153.7208
# 2                            152.1206
# 3                            149.8600
# 4                            145.3896
# ...

# %%
df_combined = pd.merge(df_combined, df_precipitation, on = ['County'], how = 'inner')
df_combined.head(3)
# Out:
#   Geo Level  State  State ANSI Ag District  Ag District Code  County  \
# 0    COUNTY  TEXAS          48  BLACKLANDS                40    BELL
# 1    COUNTY  TEXAS          48  BLACKLANDS                40  BOSQUE
# 2    COUNTY  TEXAS          48  BLACKLANDS                40  COLLIN
#
#    County ANSI COTTON-AREA-ACRES CORN-GRAIN-ACRES SORGHUM-ACRES  \
# 0         27.0          6,261.00        67,409.00      7,264.00
# 1         35.0          6,243.00         3,965.00      1,299.00
# 2         85.0            840.00        22,840.00      7,102.00
#
#   CATTLE, COWS, BEEF - INVENTORY  -  <b>VALUE</b>  \
# 0                                             (D)
# 1                                          23,500
# 2                                          17,400
#
#   CATTLE, COWS, MILK - INVENTORY  -  <b>VALUE</b>  \
# 0                                             (D)
# 1                                             NaN
# 2                                             NaN
#
# ...

# %%
df_combined.drop(['Mean Annual\nPrecipitation (in.)','Rank'],inplace = True, axis = 'columns')
df_combined.head(3)
# Out:
#   Geo Level  State  State ANSI Ag District  Ag District Code  County  \
# 0    COUNTY  TEXAS          48  BLACKLANDS                40    BELL
# 1    COUNTY  TEXAS          48  BLACKLANDS                40  BOSQUE
# 2    COUNTY  TEXAS          48  BLACKLANDS                40  COLLIN
#
#    County ANSI COTTON-AREA-ACRES CORN-GRAIN-ACRES SORGHUM-ACRES  \
# 0         27.0          6,261.00        67,409.00      7,264.00
# 1         35.0          6,243.00         3,965.00      1,299.00
# 2         85.0            840.00        22,840.00      7,102.00
#
#   CATTLE, COWS, BEEF - INVENTORY  -  <b>VALUE</b>  \
# 0                                             (D)
# 1                                          23,500
# 2                                          17,400
#
#   CATTLE, COWS, MILK - INVENTORY  -  <b>VALUE</b>  \
# 0                                             (D)
# 1                                             NaN
# 2                                             NaN
#
# ...

# %%
df_combined['Ag District'].unique()
# Out:
# array(['BLACKLANDS', 'COASTAL BEND', 'CROSS TIMBERS', 'EAST TEXAS NORTH',
#        'EAST TEXAS SOUTH', 'EDWARDS PLATEAU', 'LOWER VALLEY',
#        'NORTHERN HIGH PLAINS', 'NORTHERN LOW PLAINS', 'SOUTH CENTRAL',
#        'SOUTH TEXAS', 'SOUTHERN HIGH PLAINS', 'SOUTHERN LOW PLAINS',
#        'TRANS-PECOS', 'UPPER COAST'], dtype=object)

# %%
df_combined.head(3)
# Out:
#   Geo Level  State  State ANSI Ag District  Ag District Code  County  \
# 0    COUNTY  TEXAS          48  BLACKLANDS                40    BELL
# 1    COUNTY  TEXAS          48  BLACKLANDS                40  BOSQUE
# 2    COUNTY  TEXAS          48  BLACKLANDS                40  COLLIN
#
#    County ANSI COTTON-AREA-ACRES CORN-GRAIN-ACRES SORGHUM-ACRES  \
# 0         27.0          6,261.00        67,409.00      7,264.00
# 1         35.0          6,243.00         3,965.00      1,299.00
# 2         85.0            840.00        22,840.00      7,102.00
#
#   CATTLE, COWS, BEEF - INVENTORY  -  <b>VALUE</b>  \
# 0                                             (D)
# 1                                          23,500
# 2                                          17,400
#
#   CATTLE, COWS, MILK - INVENTORY  -  <b>VALUE</b>  \
# 0                                             (D)
# 1                                             NaN
# 2                                             NaN
#
# ...

# %%
from geopy.geocoders import Nominatim

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
class FarmGeocoder:
    def __init__(self):
        self.geocoder = Nominatim(user_agent="FarmGeocoder")

    def geocode_address(self, address):
        location = self.geocoder.geocode(address)
        return (location.latitude, location.longitude) if location else None

# Get the farm address
farm_addresses = list(df_combined.County.unique())

geocoder = FarmGeocoder()

data = []
for address in farm_addresses:
    coordinates = geocoder.geocode_address(address + ',Texas')
    if coordinates:
        latitude, longitude = coordinates
        print(f"Address: {address}")
        print(f"Latitude: {latitude}")
        print(f"Longitude: {longitude}")
        print("---------")
        data.append({'County': address, 'Latitude': latitude, 'Longitude': longitude})
    else:
        print(f"Failed to geocode address: {address}")
        print("---------")

df_geolocation = pd.DataFrame(data)
# Out:
# Address: BELL
# Latitude: 31.0081659
# Longitude: -97.4314413
# ---------
# Address: BOSQUE
# Latitude: 31.8778358
# Longitude: -97.6561014
# ---------
# Address: COLLIN
# Latitude: 33.1609629
# Longitude: -96.6060984
# ---------
# Address: COOKE
# Latitude: 33.582486
# Longitude: -97.2055298
# ---------
# Address: CORYELL
# Latitude: 31.3689333
# Longitude: -97.8184077
# ---------
# Address: DELTA
# Latitude: 33.3926893
# Longitude: -95.6749486
# ---------
# Address: DENTON
# Latitude: 33.1838787
# Longitude: -97.1413417
# ---------
# Address: ELLIS
# Latitude: 32.3347829
# Longitude: -96.7920233
# ---------
# Address: FALLS
# Latitude: 31.2320941
# Longitude: -96.9262126
# ---------
# Address: FANNIN
# Latitude: 33.5372542
# Longitude: -96.0902822
# ---------
# Address: GRAYSON
# Latitude: 33.5636114
# Longitude: -96.6702111
# ---------
# Address: HAMILTON
# Latitude: 31.6429346
# Longitude: -97.9715967
# ---------
# Address: HILL
# Latitude: 31.9595085
# Longitude: -97.0881654
# ...

# %%
df_geolocation.head(3)
# Out:
#    County   Latitude  Longitude
# 0    BELL  31.008166 -97.431441
# 1  BOSQUE  31.877836 -97.656101
# 2  COLLIN  33.160963 -96.606098

# %%
import folium

# Create a Folium map centered on the US
map_us = folium.Map(location=[39.8283, -98.5795], zoom_start=4)

# Iterate over each row in the DataFrame
for index, row in df_geolocation.iterrows():
    address = row['County']
    latitude = row['Latitude']
    longitude = row['Longitude']
    
    # Add a marker for each location
    folium.Marker(location=[latitude, longitude], popup=address).add_to(map_us)

# Display the map
map_us
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
df_combined = pd.merge(df_combined, 
                       df_geolocation, 
                       on = ['County'],
                       how = 'inner')
df_combined.head(5)
# Out:
#   Geo Level  State  State ANSI Ag District  Ag District Code   County  \
# 0    COUNTY  TEXAS          48  BLACKLANDS                40     BELL
# 1    COUNTY  TEXAS          48  BLACKLANDS                40   BOSQUE
# 2    COUNTY  TEXAS          48  BLACKLANDS                40   COLLIN
# 3    COUNTY  TEXAS          48  BLACKLANDS                40    COOKE
# 4    COUNTY  TEXAS          48  BLACKLANDS                40  CORYELL
#
#    County ANSI COTTON-AREA-ACRES CORN-GRAIN-ACRES SORGHUM-ACRES  \
# 0         27.0          6,261.00        67,409.00      7,264.00
# 1         35.0          6,243.00         3,965.00      1,299.00
# 2         85.0            840.00        22,840.00      7,102.00
# 3         97.0               NaN         3,002.00      4,870.00
# 4         99.0               NaN         1,657.00      4,705.00
#
#   CATTLE, COWS, BEEF - INVENTORY  -  <b>VALUE</b>  \
# 0                                             (D)
# 1                                          23,500
# ...

# %%
columns_list = list(df_combined.columns)
df_combined = df_combined[columns_list].replace(['(D) ',' (D)'], np.nan, regex=False)

# %%
# however the values are still in string format- convert them to float
df_combined['CATTLE, COWS, MILK - INVENTORY  -  <b>VALUE</b>'] = df_combined['CATTLE, COWS, MILK - INVENTORY  -  <b>VALUE</b>'].str.replace(',', '').astype(float)

# %%
df_combined['CATTLE, COWS, BEEF - INVENTORY  -  <b>VALUE</b>'] = df_combined['CATTLE, COWS, BEEF - INVENTORY  -  <b>VALUE</b>'].str.replace(',', '').astype(float)
df_combined['CATTLE, INCL CALVES - INVENTORY  -  <b>VALUE</b>'] = df_combined['CATTLE, INCL CALVES - INVENTORY  -  <b>VALUE</b>'].str.replace(',', '').astype(float)

# %%
df_combined.head(5)
# Out:
#   Geo Level  State  State ANSI Ag District  Ag District Code   County  \
# 0    COUNTY  TEXAS          48  BLACKLANDS                40     BELL
# 1    COUNTY  TEXAS          48  BLACKLANDS                40   BOSQUE
# 2    COUNTY  TEXAS          48  BLACKLANDS                40   COLLIN
# 3    COUNTY  TEXAS          48  BLACKLANDS                40    COOKE
# 4    COUNTY  TEXAS          48  BLACKLANDS                40  CORYELL
#
#    County ANSI COTTON-AREA-ACRES CORN-GRAIN-ACRES SORGHUM-ACRES  \
# 0         27.0          6,261.00        67,409.00      7,264.00
# 1         35.0          6,243.00         3,965.00      1,299.00
# 2         85.0            840.00        22,840.00      7,102.00
# 3         97.0               NaN         3,002.00      4,870.00
# 4         99.0               NaN         1,657.00      4,705.00
#
#    CATTLE, COWS, BEEF - INVENTORY  -  <b>VALUE</b>  \
# 0                                              NaN
# 1                                          23500.0
# ...

# %% [markdown]
# # METHANE EMISSION FROM THE CATTLE

# %%
# Define the multiplication factor
multiplication_factor = 118  # kg/head/year    ## IPCC EF DATASET

# Check if the 'cattle' column is not empty
df_combined['CH4-Kg/year-milk'] = df_combined['CATTLE, COWS, MILK - INVENTORY  -  <b>VALUE</b>'].apply(lambda x: x * multiplication_factor if pd.notnull(x) else x)

# Print the new DataFrame
df_combined.head(3)
# Out:
#   Geo Level  State  State ANSI Ag District  Ag District Code  County  \
# 0    COUNTY  TEXAS          48  BLACKLANDS                40    BELL
# 1    COUNTY  TEXAS          48  BLACKLANDS                40  BOSQUE
# 2    COUNTY  TEXAS          48  BLACKLANDS                40  COLLIN
#
#    County ANSI COTTON-AREA-ACRES CORN-GRAIN-ACRES SORGHUM-ACRES  \
# 0         27.0          6,261.00        67,409.00      7,264.00
# 1         35.0          6,243.00         3,965.00      1,299.00
# 2         85.0            840.00        22,840.00      7,102.00
#
#    CATTLE, COWS, BEEF - INVENTORY  -  <b>VALUE</b>  \
# 0                                              NaN
# 1                                          23500.0
# 2                                          17400.0
#
#    CATTLE, COWS, MILK - INVENTORY  -  <b>VALUE</b>  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
#
# ...

# %%
df_combined.columns
# Out:
# Index(['Geo Level', 'State', 'State ANSI', 'Ag District', 'Ag District Code',
#        'County', 'County ANSI', 'COTTON-AREA-ACRES', 'CORN-GRAIN-ACRES',
#        'SORGHUM-ACRES', 'CATTLE, COWS, BEEF - INVENTORY  -  <b>VALUE</b>',
#        'CATTLE, COWS, MILK - INVENTORY  -  <b>VALUE</b>',
#        'CATTLE, INCL CALVES - INVENTORY  -  <b>VALUE</b>',
#        'Mean Annual\nPrecipitation (cm.)', 'Latitude', 'Longitude',
#        'CH4-Kg/year-milk'],
#       dtype='object')

# %%
# Define the multiplication factor
multiplication_factor = 47  # kg/head/year

# Check if the 'cattle' column is not empty
df_combined['CH4-Kg/year-non-milk'] = df_combined['CATTLE, COWS, BEEF - INVENTORY  -  <b>VALUE</b>'].apply(lambda x: x * multiplication_factor if pd.notnull(x) else x)

# Print the new DataFrame
df_combined.head(5)
# Out:
#   Geo Level  State  State ANSI Ag District  Ag District Code   County  \
# 0    COUNTY  TEXAS          48  BLACKLANDS                40     BELL
# 1    COUNTY  TEXAS          48  BLACKLANDS                40   BOSQUE
# 2    COUNTY  TEXAS          48  BLACKLANDS                40   COLLIN
# 3    COUNTY  TEXAS          48  BLACKLANDS                40    COOKE
# 4    COUNTY  TEXAS          48  BLACKLANDS                40  CORYELL
#
#    County ANSI COTTON-AREA-ACRES CORN-GRAIN-ACRES SORGHUM-ACRES  \
# 0         27.0          6,261.00        67,409.00      7,264.00
# 1         35.0          6,243.00         3,965.00      1,299.00
# 2         85.0            840.00        22,840.00      7,102.00
# 3         97.0               NaN         3,002.00      4,870.00
# 4         99.0               NaN         1,657.00      4,705.00
#
#    CATTLE, COWS, BEEF - INVENTORY  -  <b>VALUE</b>  \
# 0                                              NaN
# 1                                          23500.0
# ...

# %%
# Define the multiplication factor
multiplication_factor = 47  # kg/head/year

# Check if the 'cattle' column is not empty
df_combined['CH4-Kg/year-calves'] = df_combined['CATTLE, INCL CALVES - INVENTORY  -  <b>VALUE</b>'].apply(lambda x: x * multiplication_factor if pd.notnull(x) else x)

# Print the new DataFrame
df_combined.head(3)
# Out:
#   Geo Level  State  State ANSI Ag District  Ag District Code  County  \
# 0    COUNTY  TEXAS          48  BLACKLANDS                40    BELL
# 1    COUNTY  TEXAS          48  BLACKLANDS                40  BOSQUE
# 2    COUNTY  TEXAS          48  BLACKLANDS                40  COLLIN
#
#    County ANSI COTTON-AREA-ACRES CORN-GRAIN-ACRES SORGHUM-ACRES  \
# 0         27.0          6,261.00        67,409.00      7,264.00
# 1         35.0          6,243.00         3,965.00      1,299.00
# 2         85.0            840.00        22,840.00      7,102.00
#
#    CATTLE, COWS, BEEF - INVENTORY  -  <b>VALUE</b>  \
# 0                                              NaN
# 1                                          23500.0
# 2                                          17400.0
#
#    CATTLE, COWS, MILK - INVENTORY  -  <b>VALUE</b>  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
#
# ...

# %%
columns_list = list(df_combined.columns)
columns_list
# Out:
# ['Geo Level',
#  'State',
#  'State ANSI',
#  'Ag District',
#  'Ag District Code',
#  'County',
#  'County ANSI',
#  'COTTON-AREA-ACRES',
#  'CORN-GRAIN-ACRES',
#  'SORGHUM-ACRES',
#  'CATTLE, COWS, BEEF - INVENTORY  -  <b>VALUE</b>',
#  'CATTLE, COWS, MILK - INVENTORY  -  <b>VALUE</b>',
#  'CATTLE, INCL CALVES - INVENTORY  -  <b>VALUE</b>',
#  'Mean Annual\nPrecipitation (cm.)',
#  'Latitude',
#  'Longitude',
#  'CH4-Kg/year-milk',
#  'CH4-Kg/year-non-milk',
#  'CH4-Kg/year-calves']

# %%
df_combined['Ag District'].unique()
# Out:
# array(['BLACKLANDS', 'COASTAL BEND', 'CROSS TIMBERS', 'EAST TEXAS NORTH',
#        'EAST TEXAS SOUTH', 'EDWARDS PLATEAU', 'LOWER VALLEY',
#        'NORTHERN HIGH PLAINS', 'NORTHERN LOW PLAINS', 'SOUTH CENTRAL',
#        'SOUTH TEXAS', 'SOUTHERN HIGH PLAINS', 'SOUTHERN LOW PLAINS',
#        'TRANS-PECOS', 'UPPER COAST'], dtype=object)

# %% [markdown]
# Gas	| CO2-e |
# ----| ------|
# CO2	| 1 |
# CH4	| 28 |
# N2O	| 265 |
# CF4	|6,630|
# C2F6|	12,200|
# SF6|	22,800|
# NF3|	17,200|
#
# Gas|	Conversion Factor|
# ---|-------------------|
# CO2|	3.67|
# CH4|	1.33|
# N2O|	1.57|
# Nox|	3.29|
# CO|	2.33|
# CO2 Lime|	3.67|
# NMVOC|	1.17|

# %% [markdown]
# * Region 1: 0.55
# * Region 2: 0.5
# * Region 3: 0.45
# * Region 4: 0.45
# * Region 5: 0.4
# * Region 6 :0.4
#
# #### This is categorized based on precipitation pattern. Correlation between precipitation-soil-Vegetation-[temperature] to some extent
#
# ### To reduce the multicollinearity we can consider only one factor!!

# %%
def calculate_application_factor(rainfall):
    if rainfall > 200:
      return 0.55 # this factors are for hectares of land
    elif 150 <= rainfall <= 200:
      return 0.5
    elif 100 <= rainfall < 150:
      return 0.45
    elif 50 <= rainfall < 100:
      return 0.4
    elif 25 <= rainfall < 50:
      return 0.4
    else:
        return 0.35

# %%
df_combined.columns
# Out:
# Index(['Geo Level', 'State', 'State ANSI', 'Ag District', 'Ag District Code',
#        'County', 'County ANSI', 'COTTON-AREA-ACRES', 'CORN-GRAIN-ACRES',
#        'SORGHUM-ACRES', 'CATTLE, COWS, BEEF - INVENTORY  -  <b>VALUE</b>',
#        'CATTLE, COWS, MILK - INVENTORY  -  <b>VALUE</b>',
#        'CATTLE, INCL CALVES - INVENTORY  -  <b>VALUE</b>',
#        'Mean Annual\nPrecipitation (cm.)', 'Latitude', 'Longitude',
#        'CH4-Kg/year-milk', 'CH4-Kg/year-non-milk', 'CH4-Kg/year-calves'],
#       dtype='object')

# %%
df_combined['COTTON-AREA-ACRES']
# Out:
# 0      6,261.00
# 1      6,243.00
# 2        840.00
# 3           NaN
# 4           NaN
#          ...
# 248         NaN
# 249         NaN
# 250         NaN
# 251         NaN
# 252         NaN
# Name: COTTON-AREA-ACRES, Length: 253, dtype: object

# %%
# convert the df colum cotton area acres into float for further calculation purpose
df_combined['COTTON-AREA-ACRES'] = df_combined['COTTON-AREA-ACRES'].str.replace(',', '').astype(float)
df_combined['CORN-GRAIN-ACRES'] = df_combined['CORN-GRAIN-ACRES'].str.replace(',', '').astype(float)
df_combined['SORGHUM-ACRES'] = df_combined['SORGHUM-ACRES'].str.replace(',', '').astype(float)

# %%
df_combined.head(3)
# Out:
#   Geo Level  State  State ANSI Ag District  Ag District Code  County  \
# 0    COUNTY  TEXAS          48  BLACKLANDS                40    BELL
# 1    COUNTY  TEXAS          48  BLACKLANDS                40  BOSQUE
# 2    COUNTY  TEXAS          48  BLACKLANDS                40  COLLIN
#
#    County ANSI  COTTON-AREA-ACRES  CORN-GRAIN-ACRES  SORGHUM-ACRES  \
# 0         27.0             6261.0           67409.0         7264.0
# 1         35.0             6243.0            3965.0         1299.0
# 2         85.0              840.0           22840.0         7102.0
#
#    CATTLE, COWS, BEEF - INVENTORY  -  <b>VALUE</b>  \
# 0                                              NaN
# 1                                          23500.0
# 2                                          17400.0
#
#    CATTLE, COWS, MILK - INVENTORY  -  <b>VALUE</b>  \
# 0                                              NaN
# 1                                              NaN
# ...

# %%
# Create a new column 'Application Factor' in the DataFrame
df_combined['Application Factor'] = df_combined['Mean Annual\nPrecipitation (cm.)'].apply(calculate_application_factor)

# Multiply the 'Area' column with the 'Application Factor'
df_combined['Lime-cotton-tonnes'] = df_combined['COTTON-AREA-ACRES'] * df_combined['Application Factor'] * 0.404686
df_combined['Lime-corn-tonnes'] = df_combined['CORN-GRAIN-ACRES'] * df_combined['Application Factor'] * 0.404686
df_combined['Lime-sorghum-tonnes'] = df_combined['SORGHUM-ACRES'] * df_combined['Application Factor'] * 0.404686

# %%
df_combined.head(3)
# Out:
#   Geo Level  State  State ANSI Ag District  Ag District Code  County  \
# 0    COUNTY  TEXAS          48  BLACKLANDS                40    BELL
# 1    COUNTY  TEXAS          48  BLACKLANDS                40  BOSQUE
# 2    COUNTY  TEXAS          48  BLACKLANDS                40  COLLIN
#
#    County ANSI  COTTON-AREA-ACRES  CORN-GRAIN-ACRES  SORGHUM-ACRES  \
# 0         27.0             6261.0           67409.0         7264.0
# 1         35.0             6243.0            3965.0         1299.0
# 2         85.0              840.0           22840.0         7102.0
#
#    CATTLE, COWS, BEEF - INVENTORY  -  <b>VALUE</b>  \
# 0                                              NaN
# 1                                          23500.0
# 2                                          17400.0
#
#    CATTLE, COWS, MILK - INVENTORY  -  <b>VALUE</b>  \
# 0                                              NaN
# 1                                              NaN
# ...

# %% [markdown]
# E = ((M x FracLime x P X EF) + (M x (1-FracLime) x P x EF)) x Cg/1000

# %%
FracLime = 1
P = 0.9 # PURITY OF LIMESTONE
EF = 0.12 # EMISSION FACTOR FOR LIMESTONE
Cg = 3.67

# Calculate the 'E' column:
df_combined['E-cotton-CO2'] = ((df_combined['Lime-cotton-tonnes'] * FracLime * P * EF) + (df_combined['Lime-cotton-tonnes'] * (1 - FracLime) * P * EF)) * Cg
df_combined['E-corn-CO2'] = ((df_combined['Lime-corn-tonnes'] * FracLime * P * EF) + (df_combined['Lime-corn-tonnes'] * (1 - FracLime) * P * EF)) * Cg
df_combined['E-sorghum-CO2'] = ((df_combined['Lime-sorghum-tonnes'] * FracLime * P * EF) + (df_combined['Lime-sorghum-tonnes'] * (1 - FracLime) * P * EF)) * Cg

# Display the updated DataFrame
df_combined.head(3)
# Out:
#   Geo Level  State  State ANSI Ag District  Ag District Code  County  \
# 0    COUNTY  TEXAS          48  BLACKLANDS                40    BELL
# 1    COUNTY  TEXAS          48  BLACKLANDS                40  BOSQUE
# 2    COUNTY  TEXAS          48  BLACKLANDS                40  COLLIN
#
#    County ANSI  COTTON-AREA-ACRES  CORN-GRAIN-ACRES  SORGHUM-ACRES  \
# 0         27.0             6261.0           67409.0         7264.0
# 1         35.0             6243.0            3965.0         1299.0
# 2         85.0              840.0           22840.0         7102.0
#
#    CATTLE, COWS, BEEF - INVENTORY  -  <b>VALUE</b>  \
# 0                                              NaN
# 1                                          23500.0
# 2                                          17400.0
#
#    CATTLE, COWS, MILK - INVENTORY  -  <b>VALUE</b>  \
# 0                                              NaN
# 1                                              NaN
# ...

# %% [markdown]
# # UREA

# %% [markdown]
# ## COTTON

# %%
# Conversion factor: 1 Ha = 2.47105 acres
conversion_factor = 2.47105

# Convert urea application rate from kg/Ha to kg/acre
df_combined['Urea_tonne_cotton'] = (df_combined['COTTON-AREA-ACRES'] * 270 * 0.001) / conversion_factor 

# Display the DataFrame
df_combined.head(5)
# Out:
#   Geo Level  State  State ANSI Ag District  Ag District Code   County  \
# 0    COUNTY  TEXAS          48  BLACKLANDS                40     BELL
# 1    COUNTY  TEXAS          48  BLACKLANDS                40   BOSQUE
# 2    COUNTY  TEXAS          48  BLACKLANDS                40   COLLIN
# 3    COUNTY  TEXAS          48  BLACKLANDS                40    COOKE
# 4    COUNTY  TEXAS          48  BLACKLANDS                40  CORYELL
#
#    County ANSI  COTTON-AREA-ACRES  CORN-GRAIN-ACRES  SORGHUM-ACRES  \
# 0         27.0             6261.0           67409.0         7264.0
# 1         35.0             6243.0            3965.0         1299.0
# 2         85.0              840.0           22840.0         7102.0
# 3         97.0                NaN            3002.0         4870.0
# 4         99.0                NaN            1657.0         4705.0
#
#    CATTLE, COWS, BEEF - INVENTORY  -  <b>VALUE</b>  \
# 0                                              NaN
# ...

# %%
EF = 0.20
C = 3.67

df_combined['E-cotton-urea-CO2'] = df_combined['Urea_tonne_cotton'] * EF * C
df_combined.head(5)
# Out:
#   Geo Level  State  State ANSI Ag District  Ag District Code   County  \
# 0    COUNTY  TEXAS          48  BLACKLANDS                40     BELL
# 1    COUNTY  TEXAS          48  BLACKLANDS                40   BOSQUE
# 2    COUNTY  TEXAS          48  BLACKLANDS                40   COLLIN
# 3    COUNTY  TEXAS          48  BLACKLANDS                40    COOKE
# 4    COUNTY  TEXAS          48  BLACKLANDS                40  CORYELL
#
#    County ANSI  COTTON-AREA-ACRES  CORN-GRAIN-ACRES  SORGHUM-ACRES  \
# 0         27.0             6261.0           67409.0         7264.0
# 1         35.0             6243.0            3965.0         1299.0
# 2         85.0              840.0           22840.0         7102.0
# 3         97.0                NaN            3002.0         4870.0
# 4         99.0                NaN            1657.0         4705.0
#
#    CATTLE, COWS, BEEF - INVENTORY  -  <b>VALUE</b>  \
# 0                                              NaN
# ...

# %% [markdown]
# Urea application for CORN:

# %% [markdown]
# 150 pounds * 0.453592 = kg/acre

# %% [markdown]
# https://www.derthickscornmaze.com/interesting-about-corn/how-much-urea-per-acre-for-corn.html

# %%
urea_per_acre = 150 * 0.453592 * 0.001 #tonnes per acre

df_combined['Urea_tonne_corn'] = df_combined['CORN-GRAIN-ACRES'] * urea_per_acre
df_combined.head(3)
# Out:
#   Geo Level  State  State ANSI Ag District  Ag District Code  County  \
# 0    COUNTY  TEXAS          48  BLACKLANDS                40    BELL
# 1    COUNTY  TEXAS          48  BLACKLANDS                40  BOSQUE
# 2    COUNTY  TEXAS          48  BLACKLANDS                40  COLLIN
#
#    County ANSI  COTTON-AREA-ACRES  CORN-GRAIN-ACRES  SORGHUM-ACRES  \
# 0         27.0             6261.0           67409.0         7264.0
# 1         35.0             6243.0            3965.0         1299.0
# 2         85.0              840.0           22840.0         7102.0
#
#    CATTLE, COWS, BEEF - INVENTORY  -  <b>VALUE</b>  \
# 0                                              NaN
# 1                                          23500.0
# 2                                          17400.0
#
#    CATTLE, COWS, MILK - INVENTORY  -  <b>VALUE</b>  \
# 0                                              NaN
# 1                                              NaN
# ...

# %%
EF = 0.20
C = 3.67

df_combined['E-corn-urea-CO2'] = df_combined['Urea_tonne_corn'] * EF * C
df_combined.head(5)
# Out:
#   Geo Level  State  State ANSI Ag District  Ag District Code   County  \
# 0    COUNTY  TEXAS          48  BLACKLANDS                40     BELL
# 1    COUNTY  TEXAS          48  BLACKLANDS                40   BOSQUE
# 2    COUNTY  TEXAS          48  BLACKLANDS                40   COLLIN
# 3    COUNTY  TEXAS          48  BLACKLANDS                40    COOKE
# 4    COUNTY  TEXAS          48  BLACKLANDS                40  CORYELL
#
#    County ANSI  COTTON-AREA-ACRES  CORN-GRAIN-ACRES  SORGHUM-ACRES  \
# 0         27.0             6261.0           67409.0         7264.0
# 1         35.0             6243.0            3965.0         1299.0
# 2         85.0              840.0           22840.0         7102.0
# 3         97.0                NaN            3002.0         4870.0
# 4         99.0                NaN            1657.0         4705.0
#
#    CATTLE, COWS, BEEF - INVENTORY  -  <b>VALUE</b>  \
# 0                                              NaN
# ...

# %% [markdown]
# According to the sources, the recommended urea rate for sorghum in the US is 4.535924 Kg per acre when conditions are moist and 9.071847 pounds per acre when conditions are dry

# %%
threshold = 100  # Set desired threshold value. 
factor_above_threshold = 4.5359 * 0.001 # if precipitation is above the threshold
factor_below_threshold = 9.071847 * 0.001 # if precipitation is below or equal to the threshold

df_combined['Urea_tonne_sorghum'] = np.where(df_combined['Mean Annual\nPrecipitation (cm.)'] > threshold, df_combined['SORGHUM-ACRES'] * factor_above_threshold, df_combined['SORGHUM-ACRES'] * factor_below_threshold)

# %%
df_combined.head(5)
# Out:
#   Geo Level  State  State ANSI Ag District  Ag District Code   County  \
# 0    COUNTY  TEXAS          48  BLACKLANDS                40     BELL
# 1    COUNTY  TEXAS          48  BLACKLANDS                40   BOSQUE
# 2    COUNTY  TEXAS          48  BLACKLANDS                40   COLLIN
# 3    COUNTY  TEXAS          48  BLACKLANDS                40    COOKE
# 4    COUNTY  TEXAS          48  BLACKLANDS                40  CORYELL
#
#    County ANSI  COTTON-AREA-ACRES  CORN-GRAIN-ACRES  SORGHUM-ACRES  \
# 0         27.0             6261.0           67409.0         7264.0
# 1         35.0             6243.0            3965.0         1299.0
# 2         85.0              840.0           22840.0         7102.0
# 3         97.0                NaN            3002.0         4870.0
# 4         99.0                NaN            1657.0         4705.0
#
#    CATTLE, COWS, BEEF - INVENTORY  -  <b>VALUE</b>  \
# 0                                              NaN
# ...

# %%
EF = 0.20
C = 3.67

df_combined['E-sorghum-urea-CO2'] = df_combined['Urea_tonne_sorghum'] * EF * C
df_combined.head(5)
# Out:
#   Geo Level  State  State ANSI Ag District  Ag District Code   County  \
# 0    COUNTY  TEXAS          48  BLACKLANDS                40     BELL
# 1    COUNTY  TEXAS          48  BLACKLANDS                40   BOSQUE
# 2    COUNTY  TEXAS          48  BLACKLANDS                40   COLLIN
# 3    COUNTY  TEXAS          48  BLACKLANDS                40    COOKE
# 4    COUNTY  TEXAS          48  BLACKLANDS                40  CORYELL
#
#    County ANSI  COTTON-AREA-ACRES  CORN-GRAIN-ACRES  SORGHUM-ACRES  \
# 0         27.0             6261.0           67409.0         7264.0
# 1         35.0             6243.0            3965.0         1299.0
# 2         85.0              840.0           22840.0         7102.0
# 3         97.0                NaN            3002.0         4870.0
# 4         99.0                NaN            1657.0         4705.0
#
#    CATTLE, COWS, BEEF - INVENTORY  -  <b>VALUE</b>  \
# 0                                              NaN
# ...

# %%
# replace all the NaN values with zero

df_combined = df_combined.fillna(0)
df_combined.head(5)
# Out:
#   Geo Level  State  State ANSI Ag District  Ag District Code   County  \
# 0    COUNTY  TEXAS          48  BLACKLANDS                40     BELL
# 1    COUNTY  TEXAS          48  BLACKLANDS                40   BOSQUE
# 2    COUNTY  TEXAS          48  BLACKLANDS                40   COLLIN
# 3    COUNTY  TEXAS          48  BLACKLANDS                40    COOKE
# 4    COUNTY  TEXAS          48  BLACKLANDS                40  CORYELL
#
#    County ANSI  COTTON-AREA-ACRES  CORN-GRAIN-ACRES  SORGHUM-ACRES  \
# 0         27.0             6261.0           67409.0         7264.0
# 1         35.0             6243.0            3965.0         1299.0
# 2         85.0              840.0           22840.0         7102.0
# 3         97.0                0.0            3002.0         4870.0
# 4         99.0                0.0            1657.0         4705.0
#
#    CATTLE, COWS, BEEF - INVENTORY  -  <b>VALUE</b>  \
# 0                                              0.0
# ...

# %%
df_combined['E-CH4-total-tonne'] = (df_combined['CH4-Kg/year-milk'] + df_combined['CH4-Kg/year-non-milk'] + df_combined['CH4-Kg/year-calves']) * 0.001
df_combined.head(5)
# Out:
#   Geo Level  State  State ANSI Ag District  Ag District Code   County  \
# 0    COUNTY  TEXAS          48  BLACKLANDS                40     BELL
# 1    COUNTY  TEXAS          48  BLACKLANDS                40   BOSQUE
# 2    COUNTY  TEXAS          48  BLACKLANDS                40   COLLIN
# 3    COUNTY  TEXAS          48  BLACKLANDS                40    COOKE
# 4    COUNTY  TEXAS          48  BLACKLANDS                40  CORYELL
#
#    County ANSI  COTTON-AREA-ACRES  CORN-GRAIN-ACRES  SORGHUM-ACRES  \
# 0         27.0             6261.0           67409.0         7264.0
# 1         35.0             6243.0            3965.0         1299.0
# 2         85.0              840.0           22840.0         7102.0
# 3         97.0                0.0            3002.0         4870.0
# 4         99.0                0.0            1657.0         4705.0
#
#    CATTLE, COWS, BEEF - INVENTORY  -  <b>VALUE</b>  \
# 0                                              0.0
# ...

# %% [markdown]
# # N20 emissions from Urea

# %% [markdown]
# EF
# * Non-Irrigated Crop	0.0005
# * Irrigated Crop	0.0085
# * Sugar cane	0.0199
# * Cotton	0.0055
# * Horticulture	0.0085

# %%
## Urea application * 0.46 # gives the Actual N content in the fertilizer  * Area sown * Cg 1.57 *EF
df_combined['E-NO2-cotton'] = df_combined['Urea_tonne_cotton'] * 0.46 * df_combined['COTTON-AREA-ACRES'] * 1.57 * 0.0055 * 265 * 0.001
df_combined['E-NO2-corn'] = df_combined['Urea_tonne_corn'] * 0.46 * df_combined['CORN-GRAIN-ACRES'] * 1.57 * 0.0085 * 265 * 0.001
df_combined['E-NO2-sorghum'] = df_combined['Urea_tonne_sorghum'] * 0.46 * df_combined['SORGHUM-ACRES'] * 1.57 * 0.0085 * 265 * 0.001
df_combined.head(3)
# gives in tCO2e
# Out:
#   Geo Level  State  State ANSI Ag District  Ag District Code  County  \
# 0    COUNTY  TEXAS          48  BLACKLANDS                40    BELL
# 1    COUNTY  TEXAS          48  BLACKLANDS                40  BOSQUE
# 2    COUNTY  TEXAS          48  BLACKLANDS                40  COLLIN
#
#    County ANSI  COTTON-AREA-ACRES  CORN-GRAIN-ACRES  SORGHUM-ACRES  \
# 0         27.0             6261.0           67409.0         7264.0
# 1         35.0             6243.0            3965.0         1299.0
# 2         85.0              840.0           22840.0         7102.0
#
#    CATTLE, COWS, BEEF - INVENTORY  -  <b>VALUE</b>  \
# 0                                              0.0
# 1                                          23500.0
# 2                                          17400.0
#
#    CATTLE, COWS, MILK - INVENTORY  -  <b>VALUE</b>  \
# 0                                              0.0
# 1                                              0.0
# ...

# %%
## Managment Practices
'''1. Conventional Tillage
2. Reduced Tillage
3. NoTill
'''
# Out:
# '1. Conventional Tillage\n2. Reduced Tillage\n3. NoTill\n'

# %%
# Conversion factors
g_to_kg = 0.001  # Conversion factor for grams to kilograms
ha_to_acre = 2.47105  # Conversion factor for hectares to acres
factor = (g_to_kg/ha_to_acre)*365*0.001  #tonne/acre-year

# since the data is available in g/ha - day

# %%
df_combined['Tillage'] = 'CT'

# %%
df_combined.head(3)
# Out:
#   Geo Level  State  State ANSI Ag District  Ag District Code  County  \
# 0    COUNTY  TEXAS          48  BLACKLANDS                40    BELL
# 1    COUNTY  TEXAS          48  BLACKLANDS                40  BOSQUE
# 2    COUNTY  TEXAS          48  BLACKLANDS                40  COLLIN
#
#    County ANSI  COTTON-AREA-ACRES  CORN-GRAIN-ACRES  SORGHUM-ACRES  \
# 0         27.0             6261.0           67409.0         7264.0
# 1         35.0             6243.0            3965.0         1299.0
# 2         85.0              840.0           22840.0         7102.0
#
#    CATTLE, COWS, BEEF - INVENTORY  -  <b>VALUE</b>  \
# 0                                              0.0
# 1                                          23500.0
# 2                                          17400.0
#
#    CATTLE, COWS, MILK - INVENTORY  -  <b>VALUE</b>  \
# 0                                              0.0
# 1                                              0.0
# ...

# %% [markdown]
# # assumption: if you are following CT then you are following for all the areas. No discretion to user

# %%
df_combined['E-N20-T'] = 9.1 * factor * (df_combined['COTTON-AREA-ACRES'] + df_combined['CORN-GRAIN-ACRES'] + df_combined['SORGHUM-ACRES'])
df_combined['E-CO2-T'] = 102 * factor * (df_combined['COTTON-AREA-ACRES'] + df_combined['CORN-GRAIN-ACRES'] + df_combined['SORGHUM-ACRES'])

# %%
df_combined.head(5)
# Out:
#   Geo Level  State  State ANSI Ag District  Ag District Code   County  \
# 0    COUNTY  TEXAS          48  BLACKLANDS                40     BELL
# 1    COUNTY  TEXAS          48  BLACKLANDS                40   BOSQUE
# 2    COUNTY  TEXAS          48  BLACKLANDS                40   COLLIN
# 3    COUNTY  TEXAS          48  BLACKLANDS                40    COOKE
# 4    COUNTY  TEXAS          48  BLACKLANDS                40  CORYELL
#
#    County ANSI  COTTON-AREA-ACRES  CORN-GRAIN-ACRES  SORGHUM-ACRES  \
# 0         27.0             6261.0           67409.0         7264.0
# 1         35.0             6243.0            3965.0         1299.0
# 2         85.0              840.0           22840.0         7102.0
# 3         97.0                0.0            3002.0         4870.0
# 4         99.0                0.0            1657.0         4705.0
#
#    CATTLE, COWS, BEEF - INVENTORY  -  <b>VALUE</b>  \
# 0                                              0.0
# ...

# %%
# !pip install pandas-profiling
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 18.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.3/352.3 kB 25.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 11.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.5/679.5 kB 42.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 26.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.4/455.4 kB 39.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 73.5 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=bbf6f959f35db8fb185215946bbc90f312245915122017196fd1c2940e297bd7
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# ...

# %%
from pandas_profiling import ProfileReport
profile = ProfileReport(df_combined)
profile.to_file("profile_report.html")
# Out:
# <ipython-input-79-bc314c1400a2>:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
